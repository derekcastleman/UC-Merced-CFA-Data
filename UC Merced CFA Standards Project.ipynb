# %%
import numpy as np
import pandas as pd

# %%
y = input('Current year (22-23, 23-24, etc.):   ')
# Out:
# Current year (22-23, 23-24, etc.):   23-24

# %%
cfas = input('Number of CFAs = ')
cfas = int(cfas)
# Out:
# Number of CFAs = 2

# %%
power_standards = input('Pathway for the CFA Power Standards (get rid of quotations):    ')
power_standards = pd.read_excel(power_standards)
# Out:
# Pathway for the CFA Power Standards (get rid of quotations):    C:\Users\derek.castleman\Desktop\CFA Data\Power Standards for Python.xlsx

# %%
type(cfas)
# Out:
# int

# %%
if cfas == 1:
    cfa_one_ela = input('Pathway of CFA One Standards for ELA (get rid of quotations):   ')
    cfa_one_ela = pd.read_excel(cfa_one_ela)
    cfa_one_math = input('Pathway of CFA One Standards for Math (get rid of quotations):   ')
    cfa_one_math = pd.read_excel(cfa_one_math)
elif cfas == 2:
    cfa_one_ela = input('Pathway of CFA One Standards for ELA (get rid of quotations):   ')
    cfa_one_ela = pd.read_excel(cfa_one_ela)
    cfa_one_math = input('Pathway of CFA One Standards for Math (get rid of quotations):   ')
    cfa_one_math = pd.read_excel(cfa_one_math)
    cfa_two_ela = input('Pathway of CFA Two Standards for ELA (get rid of quotations):   ')
    cfa_two_ela = pd.read_excel(cfa_two_ela)
    cfa_two_math = input('Pathway of CFA Two Standards for Math (get rid of quotations):   ')
    cfa_two_math = pd.read_excel(cfa_two_math)
elif cfas == 3:
    cfa_one_ela = input('Pathway of CFA One Standards for ELA (get rid of quotations):   ')
    cfa_one_ela = pd.read_excel(cfa_one_ela)
    cfa_one_math = input('Pathway of CFA One Standards for Math (get rid of quotations):   ')
    cfa_one_math = pd.read_excel(cfa_one_math)
    cfa_two_ela = input('Pathway of CFA Two Standards for ELA (get rid of quotations):   ')
    cfa_two_ela = pd.read_excel(cfa_two_ela)
    cfa_two_math = input('Pathway of CFA Two Standards for Math (get rid of quotations):   ')
    cfa_two_math = pd.read_excel(cfa_two_math)
    cfa_three_ela = input('Pathway of CFA Three Standards for ELA (get rid of quotations):   ')
    cfa_three_ela = pd.read_excel(cfa_three_ela)
    cfa_three_math = input('Pathway of CFA Three Standards for Math (get rid of quotations):   ')
    cfa_three_math = pd.read_excel(cfa_three_math)
elif cfas == 4:
    cfa_one_ela = input('Pathway of CFA One Standards for ELA (get rid of quotations):   ')
    cfa_one_ela = pd.read_excel(cfa_one_ela)
    cfa_one_math = input('Pathway of CFA One Standards for Math (get rid of quotations):   ')
    cfa_one_math = pd.read_excel(cfa_one_math)
    cfa_two_ela = input('Pathway of CFA Two Standards for ELA (get rid of quotations):   ')
    cfa_two_ela = pd.read_excel(cfa_two_ela)
    cfa_two_math = input('Pathway of CFA Two Standards for Math (get rid of quotations):   ')
    cfa_two_math = pd.read_excel(cfa_two_math)
    cfa_three_ela = input('Pathway of CFA Three Standards for ELA (get rid of quotations):   ')
    cfa_three_ela = pd.read_excel(cfa_three_ela)
    cfa_three_math = input('Pathway of CFA Three Standards for Math (get rid of quotations):   ')
    cfa_three_math = pd.read_excel(cfa_three_math)
    cfa_four_ela = input('Pathway of CFA Four Standards for ELA (get rid of quotations):   ')
    cfa_four_ela = pd.read_excel(cfa_four_ela)
    cfa_four_math = input('Pathway of CFA Four Standards for Math (get rid of quotations):   ')
    cfa_four_math = pd.read_excel(cfa_four_math)
# Out:
# Pathway of CFA One Standards for ELA (get rid of quotations):   C:\Users\derek.castleman\Desktop\CFA Data\CFA Data 23-24\CFA 1\ELA Standards.xls
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Pathway of CFA One Standards for Math (get rid of quotations):   C:\Users\derek.castleman\Desktop\CFA Data\CFA Data 23-24\CFA 1\Math Standards Final.xls
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Pathway of CFA Two Standards for ELA (get rid of quotations):   C:\Users\derek.castleman\Desktop\CFA Data\CFA Data 23-24\CFA 2\CFA_Standards_Marco.xlsx
# Pathway of CFA Two Standards for Math (get rid of quotations):   C:\Users\derek.castleman\Desktop\CFA Data\CFA Data 23-24\CFA 2\math2standards.xls
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
if cfas == 1:
    cfa_one_ela['Test'] = 'CFA One'
    cfa_one_ela['Subject'] = 'ELA'
    cfa_one_math['Test'] = 'CFA One'
    cfa_one_math['Subject'] = 'Math'
elif cfas == 2:
    cfa_one_ela['Test'] = 'CFA One'
    cfa_one_ela['Subject'] = 'ELA'
    cfa_one_math['Test'] = 'CFA One'
    cfa_one_math['Subject'] = 'Math'
    cfa_two_ela['Test'] = 'CFA Two'
    cfa_two_ela['Subject'] = 'ELA'
    cfa_two_math['Test'] = 'CFA Two'
    cfa_two_math['Subject'] = 'Math'
elif cfas == 3:
    cfa_one_ela['Test'] = 'CFA One'
    cfa_one_ela['Subject'] = 'ELA'
    cfa_one_math['Test'] = 'CFA One'
    cfa_one_math['Subject'] = 'Math'
    cfa_two_ela['Test'] = 'CFA Two'
    cfa_two_ela['Subject'] = 'ELA'
    cfa_two_math['Test'] = 'CFA Two'
    cfa_two_math['Subject'] = 'Math'
    cfa_three_ela['Test'] = 'CFA Three'
    cfa_three_ela['Subject'] = 'ELA'
    cfa_three_math['Test'] = 'CFA Three'
    cfa_three_math['Subject'] = 'Math'
elif cfas == 4:
    cfa_one_ela['Test'] = 'CFA One'
    cfa_one_ela['Subject'] = 'ELA'
    cfa_one_math['Test'] = 'CFA One'
    cfa_one_math['Subject'] = 'Math'
    cfa_two_ela['Test'] = 'CFA Two'
    cfa_two_ela['Subject'] = 'ELA'
    cfa_two_math['Test'] = 'CFA Two'
    cfa_two_math['Subject'] = 'Math'
    cfa_three_ela['Test'] = 'CFA Three'
    cfa_three_ela['Subject'] = 'ELA'
    cfa_three_math['Test'] = 'CFA Three'
    cfa_three_math['Subject'] = 'Math'
    cfa_four_ela['Test'] = 'CFA Four'
    cfa_four_ela['Subject'] = 'ELA'
    cfa_four_math['Test'] = 'CFA Four'
    cfa_four_math['Subject'] = 'Math'

# %%
if cfas == 1:
    cfa_data = cfa_one_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_one['Subject'] = 'ELA'
    cfa_data = cfa_one_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_one['Subject'] = 'Math'
if cfas == 2:
    cfa_data = cfa_one_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_one['Subject'] = 'ELA'
    cfa_data = cfa_one_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_one['Subject'] = 'Math'
    cfa_data = cfa_two_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_two['Subject'] = 'ELA'
    cfa_data = cfa_two_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_two['Subject'] = 'Math'
if cfas == 3:
    cfa_data = cfa_one_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_one['Subject'] = 'ELA'
    cfa_data = cfa_one_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_one['Subject'] = 'Math'
    cfa_data = cfa_two_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_two['Subject'] = 'ELA'
    cfa_data = cfa_two_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_two['Subject'] = 'Math'
    cfa_data = cfa_three_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_three['Subject'] = 'ELA'
    cfa_data = cfa_three_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_three['Subject'] = 'Math'
if cfas == 4:
    cfa_data = cfa_one_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_one['Subject'] = 'ELA'
    cfa_data = cfa_one_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_one['Subject'] = 'Math'
    cfa_data = cfa_two_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_two['Subject'] = 'ELA'
    cfa_data = cfa_two_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_two['Subject'] = 'Math'
    cfa_data = cfa_three_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_three['Subject'] = 'ELA'
    cfa_data = cfa_three_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_three['Subject'] = 'Math'
    cfa_data = cfa_four_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    ela_four = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_four['Subject'] = 'ELA'
    cfa_data = cfa_four_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Performance Band Level')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]
    math_four = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_four['Subject'] = 'Math'

# %%
if cfas == 1:
    ela_one = ela_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_one = math_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
if cfas == 2:
    ela_one = ela_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_one = math_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_two = ela_two.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_two = math_two.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
if cfas == 3:
    ela_one = ela_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_one = math_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_two = ela_two.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_two = math_two.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_three = ela_three.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_three = math_three.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
if cfas == 4:
    ela_one = ela_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_one = math_one.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_two = ela_two.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_two = math_two.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_three = ela_three.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_three = math_three.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_four = ela_four.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')
    math_four = math_four.melt(['Current Site ID','Student ID', 'Current Grade Level',
             'First Name', 'Last Name', 'Test', 'Subject'], var_name='Standard', value_name='Level')

# %%
if cfas == 1:
    ela_one = ela_one[ela_one['Level'].notna()]
    math_one = math_one[math_one['Level'].notna()]
    tests_combined = pd.concat([ela_one, math_one])
    tests_combined['Standard'] = tests_combined['Standard'].str.strip()
    final = pd.merge(tests_combined, power_standards, how='left', on=['Subject' ,'Standard'])
    final = final[~final['Standard'].isin([''])]
if cfas == 2:
    ela_one = ela_one[ela_one['Level'].notna()]
    math_one = math_one[math_one['Level'].notna()]
    ela_two = ela_two[ela_two['Level'].notna()]
    math_two = math_two[math_two['Level'].notna()]
    tests_combined = pd.concat([ela_one, math_one, ela_two, math_two])
    tests_combined['Standard'] = tests_combined['Standard'].str.strip()
    final = pd.merge(tests_combined, power_standards, how='left', on=['Subject' ,'Standard'])
    final = final[~final['Standard'].isin([''])]
if cfas == 3:
    ela_one = ela_one[ela_one['Level'].notna()]
    math_one = math_one[math_one['Level'].notna()]
    ela_two = ela_two[ela_two['Level'].notna()]
    math_two = math_two[math_two['Level'].notna()]
    ela_three = ela_three[ela_three['Level'].notna()]
    math_three = math_three[math_three['Level'].notna()]
    tests_combined = pd.concat([ela_one, math_one, ela_two, math_two, ela_three, math_three])
    tests_combined['Standard'] = tests_combined['Standard'].str.strip()
    final = pd.merge(tests_combined, power_standards, how='left', on=['Subject' ,'Standard'])
    final = final[~final['Standard'].isin([''])]
if cfas == 4:
    ela_one = ela_one[ela_one['Level'].notna()]
    math_one = math_one[math_one['Level'].notna()]
    ela_two = ela_two[ela_two['Level'].notna()]
    math_two = math_two[math_two['Level'].notna()]
    ela_three = ela_three[ela_three['Level'].notna()]
    math_three = math_three[math_three['Level'].notna()]
    ela_four = ela_four[ela_four['Level'].notna()]
    math_four = math_four[math_four['Level'].notna()]
    tests_combined = pd.concat([ela_one, math_one, ela_two, math_two, ela_three, math_three, ela_four, math_four])
    tests_combined['Standard'] = tests_combined['Standard'].str.strip()
    final = pd.merge(tests_combined, power_standards, how='left', on=['Subject' ,'Standard'])
    final = final[~final['Standard'].isin([''])]

# %%
final
# Out:
#        Current Site ID  Student ID Current Grade Level First Name  \
# 2128                 4     1095715                   K    Aaliyah
# 2129                 4     1095678                   K      Aaron
# 2130                 4     1096172                   K    Abigail
# 2131                 4     1096259                   K    Adalina
# 2132                 4     1096224                   K       Adam
# ...                ...         ...                 ...        ...
# 30245                8     1094703                  10     Yadira
# 30246                1     1093071                   9    Yesenia
# 30247                1     1095887                  10     Yulisa
# 30248                1     1094838                   9       Yuri
# 30249                1     1093789                  11    Yuridia
#
#                Last Name     Test Subject  Standard  Level Power Standard
# 2128              Cortes  CFA One     ELA  RF.K.1.d    4.0            NaN
# ...

# %%
final['Power Standard'] = final['Power Standard'].fillna(value = 'No')
final
# Out:
#        Current Site ID  Student ID Current Grade Level First Name  \
# 2128                 4     1095715                   K    Aaliyah
# 2129                 4     1095678                   K      Aaron
# 2130                 4     1096172                   K    Abigail
# 2131                 4     1096259                   K    Adalina
# 2132                 4     1096224                   K       Adam
# ...                ...         ...                 ...        ...
# 30245                8     1094703                  10     Yadira
# 30246                1     1093071                   9    Yesenia
# 30247                1     1095887                  10     Yulisa
# 30248                1     1094838                   9       Yuri
# 30249                1     1093789                  11    Yuridia
#
#                Last Name     Test Subject  Standard  Level Power Standard
# 2128              Cortes  CFA One     ELA  RF.K.1.d    4.0             No
# ...

# %%
def f(row):
    if row['Level'] >= 3:
        val = 'Yes'
    else:
        val = 'No' 
    return val

# %%
final['Standard Met'] = final.apply(f, axis=1)
final
# Out:
#        Current Site ID  Student ID Current Grade Level First Name  \
# 2128                 4     1095715                   K    Aaliyah
# 2129                 4     1095678                   K      Aaron
# 2130                 4     1096172                   K    Abigail
# 2131                 4     1096259                   K    Adalina
# 2132                 4     1096224                   K       Adam
# ...                ...         ...                 ...        ...
# 30245                8     1094703                  10     Yadira
# 30246                1     1093071                   9    Yesenia
# 30247                1     1095887                  10     Yulisa
# 30248                1     1094838                   9       Yuri
# 30249                1     1093789                  11    Yuridia
#
#                Last Name     Test Subject  Standard  Level Power Standard  \
# 2128              Cortes  CFA One     ELA  RF.K.1.d    4.0             No
# ...

# %%
if cfas == 2:
    cfa_data = cfa_one_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_one['Subject'] = 'ELA'
    cfa_data = cfa_one_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_one['Subject'] = 'Math'
    cfa_data = cfa_two_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_two['Subject'] = 'ELA'
    cfa_data = cfa_two_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_two['Subject'] = 'Math'
if cfas == 3:
    cfa_data = cfa_one_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_one['Subject'] = 'ELA'
    cfa_data = cfa_one_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_one['Subject'] = 'Math'
    cfa_data = cfa_two_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_two['Subject'] = 'ELA'
    cfa_data = cfa_two_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_two['Subject'] = 'Math'
    cfa_data = cfa_three_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_three['Subject'] = 'ELA'
    cfa_data = cfa_three_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_three['Subject'] = 'Math'
if cfas == 4:
    cfa_data = cfa_one_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_one['Subject'] = 'ELA'
    cfa_data = cfa_one_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_one = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_one['Subject'] = 'Math'
    cfa_data = cfa_two_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_two['Subject'] = 'ELA'
    cfa_data = cfa_two_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_two = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_two['Subject'] = 'Math'
    cfa_data = cfa_three_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_three['Subject'] = 'ELA'
    cfa_data = cfa_three_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    math_three = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_three['Subject'] = 'Math'
    cfa_data = cfa_four_ela
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ] 
    ela_four = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    ela_four['Subject'] = 'ELA'
    cfa_data = cfa_four_math
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Literacy.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Percent Correct')[0])
    cfa_data = cfa_data.rename(columns=lambda x: x.split('Content.')[-1])
    cfa_data = cfa_data.rename(columns=lambda x: x.split(y)[-1])
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Subject') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Scope') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Title') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Description') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Date') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Time') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Mastered') ]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Questions')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('Minutes')]
    cfa_data = cfa_data.loc[:,~cfa_data.columns.str.contains('State Student ID')]
    cfa_standards = cfa_data.loc[:,~cfa_data.columns.str.contains('Author') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Points') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Percent') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Middle Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Label') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('State Student ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency Code') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Site ID') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Current Grade Level') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('First Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Last Name') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('English Proficiency') ]
    cfa_standards = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Student Is Special Ed?') ]   
    math_four = cfa_standards.loc[:,~cfa_standards.columns.str.contains('Performance Band') ]
    math_four['Subject'] = 'Math'
else:
    pass

# %%
if cfas == 2:
    ela_one = ela_one.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_one = ela_one[~ela_one['Standard'].isin([''])]
    math_one = math_one.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_one = math_one[~math_one['Standard'].isin([''])]
    ela_two = ela_two.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_two = ela_two[~ela_two['Standard'].isin([''])]
    math_two = math_two.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_two = math_two[~math_two['Standard'].isin([''])]

if cfas == 3:
    ela_one = ela_one.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_one = ela_one[~ela_one['Standard'].isin([''])]
    math_one = math_one.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_one = math_one[~math_one['Standard'].isin([''])]
    ela_two = ela_two.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_two = ela_two[~ela_two['Standard'].isin([''])]
    math_two = math_two.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_two = math_two[~math_two['Standard'].isin([''])]
    ela_three = ela_three.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_three = ela_three[~ela_three['Standard'].isin([''])]
    math_three = math_three.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_three = math_three[~math_three['Standard'].isin([''])]
if cfas == 4:
    ela_one = ela_one.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_one = ela_one[~ela_one['Standard'].isin([''])]
    math_one = math_one.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_one = math_one[~math_one['Standard'].isin([''])]
    ela_two = ela_two.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_two = ela_two[~ela_two['Standard'].isin([''])]
    math_two = math_two.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_two = math_two[~math_two['Standard'].isin([''])]
    ela_three = ela_three.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_three = ela_three[~ela_three['Standard'].isin([''])]
    math_three = math_three.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_three = math_three[~math_three['Standard'].isin([''])]
    ela_four = ela_four.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    ela_four = ela_four[~ela_four['Standard'].isin([''])]
    math_four = math_four.melt(['Student ID','Test', 'Subject'], var_name='Standard', value_name='Level')
    math_four = math_four[~math_four['Standard'].isin([''])]
else:
    pass

# %%
if cfas == 2:
    cfa_one = pd.concat([ela_one, math_one])
    cfa_one.rename(columns = {'Test':'CFA One', 'Level': 'CFA One Level'}, inplace = True)
    cfa_two = pd.concat([ela_two, math_two])
    cfa_two.rename(columns = {'Test':'CFA Two', 'Level': 'CFA Two Level'}, inplace = True)
if cfas == 3:
    cfa_one = pd.concat([ela_one, math_one])
    cfa_one.rename(columns = {'Test':'CFA One', 'Level': 'CFA One Level'}, inplace = True)
    cfa_two = pd.concat([ela_two, math_two])
    cfa_two.rename(columns = {'Test':'CFA Two', 'Level': 'CFA Two Level'}, inplace = True)
    cfa_three = pd.concat([ela_three, math_three])
    cfa_three.rename(columns = {'Test':'CFA Three', 'Level': 'CFA Three Level'}, inplace = True)
if cfas == 4:
    cfa_one = pd.concat([ela_one, math_one])
    cfa_one.rename(columns = {'Test':'CFA One', 'Level': 'CFA One Level'}, inplace = True)
    cfa_two = pd.concat([ela_two, math_two])
    cfa_two.rename(columns = {'Test':'CFA Two', 'Level': 'CFA Two Level'}, inplace = True)
    cfa_three = pd.concat([ela_three, math_three])
    cfa_three.rename(columns = {'Test':'CFA Three', 'Level': 'CFA Three Level'}, inplace = True)
    cfa_four = pd.concat([ela_four, math_four])
    cfa_four.rename(columns = {'Test':'CFA Four', 'Level': 'CFA Four Level'}, inplace = True)
else:
    pass

# %%
if cfas == 2:
    merge = pd.merge(cfa_one, cfa_two, how='outer', on=['Student ID', 'Subject', 'Standard'])
if cfas == 3:
    merge = pd.merge(cfa_one, cfa_two, how='outer', on=['Student ID', 'Subject', 'Standard'])
    merge = pd.merge(merge, cfa_three, how='outer', on=['Student ID', 'Subject', 'Standard'])
if cfas == 4:
    merge = pd.merge(cfa_one, cfa_two, how='outer', on=['Student ID', 'Subject', 'Standard'])
    merge = pd.merge(merge, cfa_three, how='outer', on=['Student ID', 'Subject', 'Standard'])
    merge = pd.merge(merge, cfa_four, how='outer', on=['Student ID', 'Subject', 'Standard'])
else:
    pass

# %%
merge
# Out:
#         Student ID  CFA One Subject   Standard  CFA One Level  CFA Two  \
# 0          1094919  CFA One     ELA  RF.K.1.d             NaN      NaN
# 1          1094814  CFA One     ELA  RF.K.1.d             NaN      NaN
# 2          1093747  CFA One     ELA  RF.K.1.d             NaN      NaN
# 3          1095428  CFA One     ELA  RF.K.1.d             NaN      NaN
# 4          1093462  CFA One     ELA  RF.K.1.d             NaN      NaN
# ...            ...      ...     ...        ...            ...      ...
# 285620     1094774      NaN    Math    G-CO.6             NaN  CFA Two
# 285621     1095490      NaN    Math    G-CO.6             NaN  CFA Two
# 285622     1096083      NaN    Math    G-CO.6             NaN  CFA Two
# 285623     1096124      NaN    Math    G-CO.6             NaN  CFA Two
# 285624     1094136      NaN    Math    G-CO.6             NaN  CFA Two
#
#         CFA Two Level
# 0                 NaN
# 1                 NaN
# 2                 NaN
# ...

# %%
if cfas == 2:
    def f(row):
        if row['CFA Two Level'] - row['CFA One Level'] >= -100:
            val = row['CFA Two Level'] - row['CFA One Level']
        else:
            val = ''
        return val
    cfa_two = merge.loc[merge['CFA Two'] == 'CFA Two']
    cfa_two['Growth'] = cfa_two.apply(f, axis=1)
if cfas == 3:
    def f(row):
        if row['CFA Two Level'] - row['CFA One Level'] >= -100:
            val = row['CFA Two Level'] - row['CFA One Level']
        else:
            val = ''
        return val
    cfa_two = merge.loc[merge['CFA Two'] == 'CFA Two']
    cfa_two['Growth'] = cfa_two.apply(f, axis=1)
    def f(row):
        if row['CFA Three Level'] - row['CFA Two Level'] >= -100:
            val = row['CFA Three Level'] - row['CFA Two Level']
        elif row['CFA Three Level'] - row['CFA One Level'] >= -100:
            val = row['CFA Three Level'] - row['CFA One Level']
        else:
            val = ''
        return val
    cfa_three = merge.loc[merge['CFA Three'] == 'CFA Three']
    cfa_three['Growth'] = cfa_three.apply(f, axis=1)
if cfas == 4:
    def f(row):
        if row['CFA Two Level'] - row['CFA One Level'] >= -100:
            val = row['CFA Two Level'] - row['CFA One Level']
        else:
            val = ''
        return val
    cfa_two = merge.loc[merge['CFA Two'] == 'CFA Two']
    cfa_two['Growth'] = cfa_two.apply(f, axis=1)
    def f(row):
        if row['CFA Three Level'] - row['CFA Two Level'] >= -100:
            val = row['CFA Three Level'] - row['CFA Two Level']
        elif row['CFA Three Level'] - row['CFA One Level'] >= -100:
            val = row['CFA Three Level'] - row['CFA One Level']
        else:
            val = ''
        return val
    cfa_three = merge.loc[merge['CFA Three'] == 'CFA Three']
    cfa_three['Growth'] = cfa_three.apply(f, axis=1)
    def f(row):
        if row['CFA Four Level'] - row['CFA Three Level'] >= -100:
            val = row['CFA Four Level'] - row['CFA Three Level']
        elif row['CFA Four Level'] - row['CFA Two Level'] >= -100:
            val = row['CFA Four Level'] - row['CFA Two Level']
        elif row['CFA Four Level'] - row['CFA One Level'] >= -100:
            val = row['CFA Four Level'] - row['CFA One Level']
        else:
            val = ''
        return val
    cfa_four = merge.loc[merge['CFA Four'] == 'CFA CFA Four']
    cfa_four['Growth'] = cfa_four.apply(f, axis=1)
else:
    pass
# Out:
# C:\Users\DEREK~1.CAS\AppData\Local\Temp/ipykernel_6444/78340362.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cfa_two['Growth'] = cfa_two.apply(f, axis=1)

# %%
cfa_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130561 entries, 16857 to 285624
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Student ID     130561 non-null  int64
#  1   CFA One        3992 non-null    object
#  2   Subject        130561 non-null  object
#  3   Standard       130561 non-null  object
#  4   CFA One Level  341 non-null     float64
#  5   CFA Two        130561 non-null  object
#  6   CFA Two Level  10243 non-null   float64
#  7   Growth         130561 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 9.0+ MB

# %%
if cfas == 2:
    cfa_two = cfa_two.drop(['CFA One', 'CFA One Level', 'CFA Two', 'CFA Two Level'], axis=1)
if cfas == 3:
    cfa_two = cfa_two.drop(['CFA One', 'CFA One Level', 'CFA Two', 'CFA Two Level',
                                'CFA Three', 'CFA Three Level'], axis=1)
    cfa_three = cfa_three.drop(['CFA One', 'CFA One Level', 'CFA Two', 'CFA Two Level',
                                'CFA Three', 'CFA Three Level'], axis=1)
if cfas == 4:
    cfa_two = cfa_two.drop(['CFA One', 'CFA One Level', 'CFA Two', 'CFA Two Level',
                                'CFA Three', 'CFA Three Level', 'CFA Four', 'CFA Four Level'], axis=1)
    cfa_three = cfa_three.drop(['CFA One', 'CFA One Level', 'CFA Two', 'CFA Two Level',
                                'CFA Three', 'CFA Three Level', 'CFA Four', 'CFA Four Level'], axis=1)
    cfa_four = cfa_four.drop(['CFA One', 'CFA One Level', 'CFA Two', 'CFA Two Level',
                                'CFA Three', 'CFA Three Level', 'CFA Four', 'CFA Four Level'], axis=1)
else:
    pass

# %%
if cfas == 2:
    mask = cfa_two['Growth'] == ''
    cfa_two = cfa_two[~mask]
    cfa_two['Standard'] = cfa_two['Standard'].str.strip()
if cfas == 3:
    mask = cfa_two['Growth'] == ''
    cfa_two = cfa_two[~mask]
    cfa_two['Standard'] = cfa_two['Standard'].str.strip()
    mask = cfa_three['Growth'] == ''
    cfa_three = cfa_three[~mask]
    cfa_three['Standard'] = cfa_three['Standard'].str.strip()
if cfas == 4:
    mask = cfa_two['Growth'] == ''
    cfa_two = cfa_two[~mask]
    cfa_two['Standard'] = cfa_two['Standard'].str.strip()
    mask = cfa_three['Growth'] == ''
    cfa_three = cfa_three[~mask]
    cfa_three['Standard'] = cfa_three['Standard'].str.strip()
    mask = cfa_four['Growth'] == ''
    cfa_four = cfa_four[~mask]
    cfa_four['Standard'] = cfa_four['Standard'].str.strip()
else:
    pass

# %%
final
# Out:
#        Current Site ID  Student ID Current Grade Level First Name  \
# 2128                 4     1095715                   K    Aaliyah
# 2129                 4     1095678                   K      Aaron
# 2130                 4     1096172                   K    Abigail
# 2131                 4     1096259                   K    Adalina
# 2132                 4     1096224                   K       Adam
# ...                ...         ...                 ...        ...
# 30245                8     1094703                  10     Yadira
# 30246                1     1093071                   9    Yesenia
# 30247                1     1095887                  10     Yulisa
# 30248                1     1094838                   9       Yuri
# 30249                1     1093789                  11    Yuridia
#
#                Last Name     Test Subject  Standard  Level Power Standard  \
# 2128              Cortes  CFA One     ELA  RF.K.1.d    4.0             No
# ...

# %%
if cfas == 1:
    final = final
if cfas == 2:
    cfa_second = final.loc[final['Test'] == 'CFA Two']
    cfa_first = final.loc[final['Test'] == 'CFA One']
    growth_one = pd.merge(cfa_second, cfa_two, how='left', on=['Student ID', 'Subject', 'Standard'])
    final = pd.concat([cfa_first, growth_one])
if cfas == 3:
    cfa_second = final.loc[final['Test'] == 'CFA Two']
    cfa_first = final.loc[final['Test'] == 'CFA One']
    growth_one = pd.merge(cfa_second, cfa_two, how='left', on=['Student ID', 'Subject', 'Standard'])
    cfa_third = final.loc[final['Test'] == 'CFA Three']
    growth_two = pd.merge(cfa_third, cfa_three, how='left', on=['Student ID', 'Subject', 'Standard'])
    final = pd.concat([cfa_first, growth_one, growth_two])
if cfas == 4:
    cfa_second = final.loc[final['Test'] == 'CFA Two']
    cfa_first = final.loc[final['Test'] == 'CFA One']
    growth_one = pd.merge(cfa_second, cfa_two, how='left', on=['Student ID', 'Subject', 'Standard'])
    cfa_third = final.loc[final['Test'] == 'CFA Three']
    growth_two = pd.merge(cfa_third, cfa_three, how='left', on=['Student ID', 'Subject', 'Standard'])
    cfa_fourth = final.loc[final['Test'] == 'CFA Four']
    growth_three = pd.merge(cfa_fourth, cfa_four, how='left', on=['Student ID', 'Subject', 'Standard'])
    final = pd.concat([cfa_first, growth_one, growth_two, growth_three])
else:
    pass

# %%
final['Growth'] = final['Growth'].astype(float)
final['Growth'] = final['Growth'].round(2)
final
# Out:
#        Current Site ID  Student ID Current Grade Level First Name  \
# 2128                 4     1095715                   K    Aaliyah
# 2129                 4     1095678                   K      Aaron
# 2130                 4     1096172                   K    Abigail
# 2131                 4     1096259                   K    Adalina
# 2132                 4     1096224                   K       Adam
# ...                ...         ...                 ...        ...
# 10238                8     1094703                  10     Yadira
# 10239                1     1093071                   9    Yesenia
# 10240                1     1095887                  10     Yulisa
# 10241                1     1094838                   9       Yuri
# 10242                1     1093789                  11    Yuridia
#
#                Last Name     Test Subject  Standard  Level Power Standard  \
# 2128              Cortes  CFA One     ELA  RF.K.1.d    4.0             No
# ...

# %%
import base64
from IPython.display import HTML

def create_download_link( df, title = "CFA Standards for Merced", filename = "CFA Standards for Merced"):
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(final)
# Out:
# <a download="CFA Standards for Merced" href="data:text/csv;base64,..." target="_blank">CFA Standards for Merced</a>
